# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd 
import cv2                 
import numpy as np         
import os                  
from random import shuffle
from tqdm import tqdm  
import scipy
import skimage
from skimage.transform import resize
from PIL import Image
import sklearn

# %% [markdown]
# # Pristup datasetu

# %%
print(os.listdir("/kaggle/input/papsmeardatasets/"))
Herlev = "/kaggle/input/papsmeardatasets/herlev_pap_smear/"
Sipak = "/kaggle/input/papsmeardatasets/sipakmed_fci_pap_smear/"
# Out:
# ['herlev_pap_smear', 'sipakmed_wsi_pap_smear', 'sipakmed_fci_pap_smear']

# %%
Lista_H = os.listdir(Herlev)

# %% [markdown]
# Resizeanje slika na 64 x 64 za CNN.
# Davanje labela ( abnormalna = 1, normalna = 0).
# Vraća listu slika i labela.

# %%
def get_data(Dir):
    X = []
    y = []
    
    for dir_name in Dir:
        for nextDir in os.listdir(dir_name):
            if not nextDir.startswith('.'):
                if nextDir.startswith('normal'):
                    label = 0
                elif nextDir.startswith('abnormal') or nextDir.startswith('benign'):
                    label = 1
                


                temp = dir_name + nextDir

                for file in tqdm(os.listdir(temp)):
                    if not file.endswith('d.bmp') and not file.endswith('dat'):
                        img = cv2.imread(temp + '/' + file)
                        if img is not None:
                            img = skimage.transform.resize(img, (64,64,3))
                            #img_file = scipy.misc.imresize(arr=img_file, size=(150, 150, 3))
                            img = np.asarray(img)
                            X.append(img)
                            y.append(label)
                    
    X = np.asarray(X)
    y = np.asarray(y)
    return X,y

# %%
Lista = [Herlev, Sipak]

# %% [markdown]
# Postavljamo X_train na sve slike, y_train sve labele.

# %%
X_train, y_train = get_data(Lista)
# Out:
# 100%|██████████| 196/196 [00:00<00:00, 404.20it/s]
# 100%|██████████| 394/394 [00:00<00:00, 492.17it/s]
# 100%|██████████| 364/364 [00:01<00:00, 325.23it/s]
# 100%|██████████| 148/148 [00:01<00:00, 139.80it/s]
# 100%|██████████| 140/140 [00:00<00:00, 187.93it/s]
# 100%|██████████| 300/300 [00:00<00:00, 541.58it/s]
# 100%|██████████| 292/292 [00:00<00:00, 412.06it/s]
# 100%|██████████| 2475/2475 [00:05<00:00, 483.19it/s]
# 100%|██████████| 2379/2379 [00:05<00:00, 440.86it/s]
# 100%|██████████| 2439/2439 [00:03<00:00, 651.86it/s]
# 100%|██████████| 2361/2361 [00:05<00:00, 441.67it/s]
# 100%|██████████| 2493/2493 [00:12<00:00, 195.71it/s]

# %% [markdown]
# Import-anje svega što će nam trebati za izradu modela, te matplot.pyplot za crtanje grafova.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
import tensorflow as tf
from sklearn.model_selection import train_test_split
from PIL import Image
from keras.utils.vis_utils import plot_model
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Dijelimo dataset na trening i test. 85% dataseta koristimo za model, 15% za testiranje.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.15)

# %% [markdown]
# Ispod je CNN za binarnu klasifikaciju (napravljen originalno za klasifikaciju mačaka i pasa, malo prilagođen)

# %% [markdown]
# Za metriku se koristi Accuracy (osnovna metrika)  i Recall jer nas zanima koliko imamo FN rezultata, koje želimo izbjeći.

# %% [markdown]
# Na slici dolje se može vidjeti kako mreža izgleda po slojevima.

# %%
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(64, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a third convolutional layer
classifier.add(Conv2D(128, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a fourth convolutional layer
classifier.add(Conv2D(128, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dropout(0.4))
classifier.add(Dense(units = 64, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics =["accuracy",tf.keras.metrics.Recall(
    thresholds=None, top_k=None, class_id=None, name=None, dtype=None
)])
#metrics =[ tf.keras.metrics.Recall()]
plot_model(classifier, to_file='cnn_model.png', show_shapes=True, show_layer_names=True)
display(Image.open('cnn_model.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=527x1401 at 0x7F39A0604F10>

# %% [markdown]
# Treniranje mreže, 20 epoha, 10% se koristi za validaciju.

# %%
classifier.fit(X_train, y_train,validation_split = 0.1,  epochs=20)
# Out:
# Train on 3798 samples, validate on 423 samples
# Epoch 1/20
# 3798/3798 [==============================] - 15s 4ms/step - loss: 0.5414 - accuracy: 0.7159 - recall: 0.8298 - val_loss: 0.4245 - val_accuracy: 0.8061 - val_recall: 0.8238
# Epoch 2/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.3928 - accuracy: 0.8273 - recall: 0.8290 - val_loss: 0.4037 - val_accuracy: 0.8227 - val_recall: 0.8367
# Epoch 3/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.3716 - accuracy: 0.8333 - recall: 0.8393 - val_loss: 0.3731 - val_accuracy: 0.8392 - val_recall: 0.8458
# Epoch 4/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.3342 - accuracy: 0.8602 - recall: 0.8520 - val_loss: 0.3636 - val_accuracy: 0.8511 - val_recall: 0.8558
# Epoch 5/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.3127 - accuracy: 0.8705 - recall: 0.8591 - val_loss: 0.3257 - val_accuracy: 0.8582 - val_recall: 0.8634
# Epoch 6/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.2971 - accuracy: 0.8791 - recall: 0.8669 - val_loss: 0.3176 - val_accuracy: 0.8534 - val_recall: 0.8702
# Epoch 7/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.3101 - accuracy: 0.8749 - recall: 0.8726 - val_loss: 0.3699 - val_accuracy: 0.8676 - val_recall: 0.8746
# Epoch 8/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.3044 - accuracy: 0.8723 - recall: 0.8758 - val_loss: 0.2985 - val_accuracy: 0.8771 - val_recall: 0.8773
# Epoch 9/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.2900 - accuracy: 0.8873 - recall: 0.8793 - val_loss: 0.3053 - val_accuracy: 0.8747 - val_recall: 0.8815
# Epoch 10/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.2713 - accuracy: 0.8957 - recall: 0.8836 - val_loss: 0.3126 - val_accuracy: 0.8723 - val_recall: 0.8855
# Epoch 11/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.2642 - accuracy: 0.8960 - recall: 0.8875 - val_loss: 0.2756 - val_accuracy: 0.9007 - val_recall: 0.8893
# Epoch 12/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.2605 - accuracy: 0.8939 - recall: 0.8904 - val_loss: 0.3162 - val_accuracy: 0.8605 - val_recall: 0.8921
# Epoch 13/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.2333 - accuracy: 0.9147 - recall: 0.8937 - val_loss: 0.2994 - val_accuracy: 0.8960 - val_recall: 0.8952
# Epoch 14/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.2272 - accuracy: 0.9131 - recall: 0.8966 - val_loss: 0.2405 - val_accuracy: 0.8960 - val_recall: 0.8982
# Epoch 15/20
# 3798/3798 [==============================] - 15s 4ms/step - loss: 0.1973 - accuracy: 0.9258 - recall: 0.8999 - val_loss: 0.2866 - val_accuracy: 0.8983 - val_recall: 0.9017
# Epoch 16/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.2093 - accuracy: 0.9200 - recall: 0.9030 - val_loss: 0.2412 - val_accuracy: 0.9173 - val_recall: 0.9043
# Epoch 17/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.1896 - accuracy: 0.9250 - recall: 0.9057 - val_loss: 0.3007 - val_accuracy: 0.8913 - val_recall: 0.9069
# Epoch 18/20
# 3798/3798 [==============================] - 14s 4ms/step - loss: 0.1800 - accuracy: 0.9360 - recall: 0.9082 - val_loss: 0.2147 - val_accuracy: 0.9149 - val_recall: 0.9097
# Epoch 19/20
# 3798/3798 [==============================] - 15s 4ms/step - loss: 0.1575 - accuracy: 0.9423 - recall: 0.9111 - val_loss: 0.2145 - val_accuracy: 0.9291 - val_recall: 0.9125
# Epoch 20/20
# 3798/3798 [==============================] - 17s 4ms/step - loss: 0.1582 - accuracy: 0.9442 - recall: 0.9139 - val_loss: 0.2150 - val_accuracy: 0.9267 - val_recall: 0.9152

# %% [markdown]
# Na trening setu od 3798 slika i validacijskom setu od 423 uvježban je CNN.

# %%
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
print(classifier.history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'val_recall', 'loss', 'accuracy', 'recall'])

# %% [markdown]
# ## Grafovi

# %%
plt.plot(classifier.history.history['accuracy'])
plt.plot(classifier.history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

#history1.history['val_loss']
# Plot training & validation loss values
plt.plot(classifier.history.history['loss'])
plt.plot(classifier.history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# Na prvom grafu je prikazana usporedba accuracya na trening i validacijskom setu kroz epohe.
# Na drugom grafu je prikazana vrijednost loss funkcije kroz epohe na trening i validacijskom setu.

# %%
classifier.save('Cell_predict')

# %%
new_model = tf.keras.models.load_model('Cell_predict')

# %% [markdown]
# Predviđanje na testnom setu.

# %%
predictions = new_model.predict([X_test])

# %% [markdown]
# Pomoćni niz za precision i recall graf

# %%
niz = np.arange(0.0, 1.01, 0.01)

# %% [markdown]
# pomoćna funkcija za precision i recall graf

# %%
def zaok(a, x):
    if a >= x:
        return 1
    else:
        return 0

# %% [markdown]
# # Proučavanje predikcije za test set od 745 slika

# %%
y_test[0] == np.rint(predictions[0])
# Out:
# array([ True])

# %% [markdown]
# ## Prebrojavanje TP, TN, FP, FN

# %%
TP = 0
FP = 0
TN = 0
FN = 0
for (i, j) in zip (y_test, predictions):
    if i == 0:
        if i == np.rint(j):
            TN += 1
        else:
            FP += 1
    elif i == 1:
        if i == np.rint(j):
            TP += 1
        else:
            FN += 1

# %%
print(TP, FP, TN, FN)
# Out:
# 466 28 235 16

# %% [markdown]
# Funkcije za računanje precisiona i recalla.

# %%
def prec(TP,FP):
    return TP/(TP+FP)
def rec(TP, FN):
    return TP/(TP+FN)

# %% [markdown]
# ## nizovi precision i recall za graf

# %% [markdown]
# Mijenjamo "odlučujuću" vrijednost za određivanje klase stanice.

# %%
precision = []
recall = []
pom_pred = []

for k in niz:
    TP_1 = 0
    FP_1 = 0
    TN_1 = 0
    FN_1 = 0
    for (i, j) in zip (y_test, predictions):
        if i == 0:
            if i == zaok(j, k):
                TN_1 += 1
            else:
                FP_1 += 1
        elif i == 1:
            if i == zaok(j, k):
                TP_1 += 1
            else:
                FN_1 += 1
    precision.append(prec(TP_1,FP_1))
    recall.append(rec(TP_1,FN_1))

# %% [markdown]
# ### Broj pogrešnih predikcija

# %%
brojac = 0

for (i, j) in zip (y_test, predictions):
    if i != np.rint(j):
        brojac += 1

# %% [markdown]
# ### Accuracy

# %%
accu = 1 - brojac/len(y_test)

# %%
print('Accuracy je:', accu)
# Out:
# Accuracy je: 0.9409395973154362

# %% [markdown]
# Recall

# %%
Rec_ = TP/(FN+TP)

# %%
print(Rec_)
# Out:
# 0.966804979253112

# %% [markdown]
# Precision

# %%
Pre_ = TP/(FP+TP)

# %%
print(Pre_)
# Out:
# 0.9433198380566802

# %% [markdown]
# Graf: Precision i recall, u ovisnosti o "decision" funkciji.

# %%
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.annotate('Najbolji Recall i precision', xy=(Rec_, Pre_), xytext=(1, 1.1),
            arrowprops=dict(facecolor='black', shrink=0.002),
            )
# Out:
# Text(1, 1.1, 'Najbolji Recall i precision')

# %% [markdown]
# # Matrica konfuzije

# %% [markdown]
# arr je niz predviđanja za testni set (niz nula i jedinica)

# %%
arr = np.rint(predictions)

# %%
cm = sklearn.metrics.confusion_matrix(y_test,arr)

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
cm
# Out:
# array([[235,  28],
#        [ 16, 466]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cn = sns.light_palette("blue", as_cmap=True)
x=pd.DataFrame(cm)
x=x.style.background_gradient(cmap=cn)
display(x)
# Out:
# <style  type="text/css" >
#     #T_7367d0c8_b0cb_11ea_a538_0242ac130202row0_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_7367d0c8_b0cb_11ea_a538_0242ac130202row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_7367d0c8_b0cb_11ea_a538_0242ac130202row1_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_7367d0c8_b0cb_11ea_a538_0242ac130202row1_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_7367d0c8_b0cb_11ea_a538_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7367d0c8_b0cb_11ea_a538_0242ac130202level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7367d0c8_b0cb_11ea_a538_0242ac130202row0_col0" class="data row0 col0" >235</td>
#                         <td id="T_7367d0c8_b0cb_11ea_a538_0242ac130202row0_col1" class="data row0 col1" >28</td>
#             </tr>
#             <tr>
#                         <th id="T_7367d0c8_b0cb_11ea_a538_0242ac130202level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7367d0c8_b0cb_11ea_a538_0242ac130202row1_col0" class="data row1 col0" >16</td>
#                         <td id="T_7367d0c8_b0cb_11ea_a538_0242ac130202row1_col1" class="data row1 col1" >466</td>
#             </tr>
#     </tbody></table>

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools

# %% [markdown]
# ## Matrica konfuzije veća

# %%
plt.imshow(cm, interpolation='nearest', cmap=cn)
plt.title("Matrica konfuzije")
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['Negative', 'Positive'], rotation=45)
plt.yticks(tick_marks, ['P', 'N'])

#if normalize:
#    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#    print("Normalized confusion matrix")
#else:
#    print('Confusion matrix, without normalization')

#print(cm)

thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, -13.802484617611796, 'Predicted label')
